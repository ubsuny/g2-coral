# %% [markdown]
# ## Using Monte Carlo to get simulated data
# #### done in numpy first

# %%
# import libraries we need
# %pylab inline
import sys
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# set parameters
dt = 2.34e-9
tmax = 400e-9
Nbin = 215
R = 1/(20*Nbin)
Nco = 1/R*10
n = 0

'''
dt -> time bin size in sec
tmax -> max time delay in sec
Nbin -> number of bins
R -> co-detection rate per bin
Nco -> total detections
n -> number of count
'''
# Out:
# '\ndt -> time bin size in sec\ntmax -> max time delay in sec\nNbin -> number of bins\nR -> co-detection rate per bin\nNco -> total detections\nn -> number of count\n'

# %%
r1 = np.arange(-100,0,1)
r2 = np.arange(1,116,1)
r = np.concatenate((r1,r2))

# %%
# setup events
p1 = n
p2 = []
binlist = []
Nco = 100000   # number of counts

for i in np.arange(Nbin):
    binlist.append(i)

for i in np.arange(Nco):
    p2det = np.random.choice(r)#,p=probability)
    p2.append(p2det)
    #print(p2det)
p2 = np.stack(p2)

# %%
hist = plt.hist(p2,bins=Nbin+1)

# %%
y = hist[0]/np.average(hist[0][:100])
plt.plot(y)

# %%
# 
nbin = np.arange(Nbin)
photon1 = 0    # 1st photon arrives at 0th bin
photon2 =
# Out:
#   File "<ipython-input-104-0d398e306fe2>", line 4
#     photon2 =
#               ^
# SyntaxError: invalid syntax
